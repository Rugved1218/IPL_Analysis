# %%
import pandas as pd

# Read the CSV (if it's copied as above, save it as 'ipl.csv')
df = pd.read_csv(r"../datasets/iplAnalysis1.csv")

# Rename columns to shorter names (optional, just an example)
df.columns = [
    'Sr no.','Player', 'Team', 'Role', 'Matches', 'Innings', 'NotOuts', 'BallsPlayed', 'RunsScored',
    'BatAvg', 'BatSR', '50+ Scores', '100+ Scores', 'Wickets', 'BowlInnings', 'BallsBowled', 
    'OversBowled', 'RunsConceded', 'BowlEco', 'BowlAvg', 'BowlSR', '4W', '5W'
]

# Show basic info
print("DataFrame Info")
print(df.info())
print()

# Count missing values
print("No of missing values")
print(df.isnull().sum())
print()

# Replace missing values with 0
df.fillna(0, inplace=True)
print("Dataframe after filling missing values")
print(df)
print()

# Round off numerical columns to 2 decimal places
columns = ['BatAvg', 'BatSR', 'OversBowled', 'BowlEco', 'BowlAvg', 'BowlSR']
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce').round(2)
    print("DataFrame after rounding the columns to 2 places")
    print(df)

# Convert balls bowled to integer
df['BallsBowled'] = pd.to_numeric(df['BallsBowled'], errors='coerce').fillna(0).astype(int)

# Check for impossible values
print("Columns with impossible values")
print()

print("Players with more than 400 sr")
print(df[df['BatSR'] > 400])
print()

print("Players with less than 0 matches played")
print(df[df['Matches'] < 0])
print()

print("Players with bowling economy less than 0")
print(df[df['BowlEco'] < 0])
print()

# Check duplicates
print("Checking for duplicates")
print(df[df.duplicated()])

# Save cleaned DataFrame to new CSV
df.to_csv(r"../datasets/iplAnalysisCleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       4 df = pd.read_csv(r"../datasets/iplAnalysis1.csv")
#       6 # Rename columns to shorter names (optional, just an example)
# ----> 7 df.columns = [
#       8     'Player', 'Team', 'Role', 'Matches', 'Innings', 'NotOuts', 'BallsPlayed', 'RunsScored',
#       9     'BatAvg', 'BatSR', '50+ Scores', '100+ Scores', 'Wickets', 'BowlInnings', 'BallsBowled',
#      10     'OversBowled', 'RunsConceded', 'BowlEco', 'BowlAvg', 'BowlSR', '4W', '5W'
#      11 ]
#      13 # Show basic info
#      14 print("DataFrame Info")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
#     818 self._clear_item_cache()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 23 elements, new values have 22 elements
